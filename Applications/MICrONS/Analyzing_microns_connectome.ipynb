# %%
# %load_ext autoreload
# %autoreload 2

# %%
import networkx as nx
import pickle

# %% [markdown]
# # Load minnie65 Connectome

# %%
connectome_path = "../Data/minnie65_multidigraph.pkl"

with open(connectome_path, "rb") as f:
    G = pickle.load(f)

G

# %% [markdown]
# # Setting the node in degree and out degree

# %%
len(G.nodes())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 len(G.nodes())
#
# NameError: name 'G' is not defined

# %%
import networkx as nx

# Add in-degree and out-degree as node attributes
in_degree_dict = dict(G.in_degree())
out_degree_dict = dict(G.out_degree())
nx.set_node_attributes(G, dict(G.in_degree()), "in_degree")
nx.set_node_attributes(G, dict(G.out_degree()), "out_degree")
nx.set_node_attributes(G, dict(G.degree()),"total_degree")

# %% [markdown]
# # Look at the features of a certain node

# %%
nodes = list(G.nodes())
nodes[:10]
# Out:
# ['864691136023767609_0',
#  '864691136965808334_0',
#  '864691135617737103_0',
#  '864691134939970403_0',
#  '864691135497605139_0',
#  '864691135366598130_0',
#  '864691135385264469_0',
#  '864691136296739099_0',
#  '864691135939472385_0',
#  '864691136023727417_0']

# %%
n = "864691136965808334_0"
G.nodes[n]
# Out:
# {'segment_id': 864691136965808334,
#  'split_index': 0,
#  'multiplicity': 1,
#  'cell_type_used': 'baylor',
#  'cell_type': 'excitatory',
#  'nucleus_id': 33321,
#  'nuclei_distance': 490.34,
#  'n_nuclei_in_radius': 1,
#  'n_nuclei_in_bbox': 1,
#  'centroid_x': 73773,
#  'centroid_y': 167723,
#  'centroid_z': 19855,
#  'centroid_x_nm': 295092.4139694181,
#  'centroid_y_nm': 670893.6067298498,
#  'centroid_z_nm': 794203.913531376,
#  'centroid_volume': 410.54936253946556,
#  'max_soma_n_faces': 24877,
#  'max_soma_volume': 639,
#  'max_soma_area': 358,
#  'syn_density_post_after_proof': 0.4050608177925558,
#  'syn_density_head_after_proof': 0.16643588057812936,
#  'syn_density_neck_after_proof': 0.0020052515732304744,
#  'syn_density_shaft_after_proof': 0.18849364788366457,
#  'skeletal_length_processed_syn_after_proof': 498690.54504168424,
#  'spine_density_after_proof': 0.25174413039889243,
#  'skeletal_length_processed_spine_after_proof': 432979.3104899322,
#  'baylor_cell_type_after_proof': 'excitatory',
#  'baylor_cell_type_exc_probability_after_proof': 0.8551275384999161,
#  'baylor_cell_type': 'excitatory',
#  'baylor_cell_type_exc_probability': 0.8543908203964665,
#  'external_cell_type': 'excitatory',
#  'cell_type_used_for_axon': 'baylor',
#  'cell_type_for_axon': 'excitatory',
#  'external_cell_type_n_nuc': 1,
#  'external_cell_type_fine': '4P',
#  'external_layer': 'LAYER4',
#  'external_visual_area': 'V1',
#  'axon_angle_max': 156.91,
#  'axon_angle_min': 156.91,
#  'n_axon_angles': 1,
#  'axon_start_distance_from_soma': 0.0,
#  'n_vertices': 70542,
#  'n_faces': 140541,
#  'n_limbs': 7,
#  'n_branches': 11,
#  'max_limb_n_branches': 3,
#  'skeletal_length': 527835.3829522169,
#  'max_limb_skeletal_length': 225438.30069088604,
#  'median_branch_length': 24101.837,
#  'width_median': 264.927,
#  'width_no_spine_median': 260.092,
#  'width_90_perc': 398.267,
#  'width_no_spine_90_perc': 396.526,
#  'n_spines': 113,
#  'n_boutons': 0,
#  'spines_per_branch': 10.272727272727273,
#  'skeletal_length_eligible': 527835.383,
#  'n_spine_eligible_branches': 11,
#  'spine_density_eligible': 0.00021408189681744013,
#  'spines_per_branch_eligible': 10.273,
#  'total_spine_volume': 60016971933.422745,
#  'spine_volume_median': 228722305.21268922,
#  'spine_volume_density': 113703.95746822428,
#  'spine_volume_density_eligible': 113703.95745793104,
#  'spine_volume_per_branch_eligible': 5456088357.583886,
#  'dendrite_skeletal_length': 507615,
#  'dendrite_area': 1559,
#  'dendrite_mesh_volume': 14813,
#  'dendrite_n_branches': 10,
#  'axon_skeletal_length': 20220,
#  'axon_area': 31,
#  'axon_mesh_volume': 29,
#  'axon_n_branches': 1,
#  'basal_skeletal_length': 282177,
#  'basal_area': 691,
#  'basal_mesh_volume': 5389,
#  'basal_n_branches': 7,
#  'apical_skeletal_length': 29217,
#  'apical_area': 46,
#  'apical_mesh_volume': 172,
#  'apical_n_branches': 1,
#  'apical_tuft_skeletal_length': 0,
#  'apical_tuft_area': 0,
#  'apical_tuft_mesh_volume': 0,
#  'apical_tuft_n_branches': 0,
#  'apical_shaft_skeletal_length': 196221,
#  'apical_shaft_area': 821,
#  'apical_shaft_mesh_volume': 9253,
#  'apical_shaft_n_branches': 2,
#  'oblique_skeletal_length': 0,
#  'oblique_area': 0,
#  'oblique_mesh_volume': 0,
#  'oblique_n_branches': 0,
#  'apical_total_skeletal_length': 225438,
#  'apical_total_area': 867,
#  'apical_total_mesh_volume': 9425,
#  'apical_total_n_branches': 3,
#  'n_syn_valid': 240,
#  'n_syn_valid_pre': 0,
#  'n_syn_valid_post': 240,
#  'n_syn_error': 160,
#  'n_syn_error_pre': 158,
#  'n_syn_error_post': 2,
#  'n_syn_presyns_on_dendrite': 4,
#  'n_syn_mesh_errored': 156,
#  'n_syn_distance_errored': 0,
#  'n_syn_no_label': 36,
#  'n_syn_head': 84,
#  'n_syn_neck': 1,
#  'n_syn_shaft': 95,
#  'n_syn_no_head': 28,
#  'n_syn_bouton': 0,
#  'n_syn_non_bouton': 0,
#  'n_syn_dendrite': 204,
#  'n_syn_axon': 0,
#  'n_syn_basal': 117,
#  'n_syn_apical': 5,
#  'n_syn_apical_tuft': 0,
#  'n_syn_apical_shaft': 82,
#  'n_syn_oblique': 0,
#  'n_syn_soma': 36,
#  'n_syn_apical_total': 87,
#  'n_syn_dendrite_head_postsyn': 83,
#  'n_syn_dendrite_neck_postsyn': 1,
#  'n_syn_dendrite_shaft_postsyn': 92,
#  'n_syn_dendrite_no_head_postsyn': 28,
#  'n_syn_axon_bouton_presyn': 0,
#  'n_syn_axon_bouton_postsyn': 0,
#  'n_syn_axon_non_bouton_presyn': 0,
#  'n_syn_axon_non_bouton_postsyn': 0,
#  'n_syn_basal_head_postsyn': 50,
#  'n_syn_basal_neck_postsyn': 1,
#  'n_syn_basal_shaft_postsyn': 52,
#  'n_syn_basal_no_head_postsyn': 14,
#  'n_syn_apical_head_postsyn': 0,
#  'n_syn_apical_neck_postsyn': 0,
#  'n_syn_apical_shaft_postsyn': 5,
#  'n_syn_apical_no_head_postsyn': 0,
#  'n_syn_apical_tuft_head_postsyn': 0,
#  'n_syn_apical_tuft_neck_postsyn': 0,
#  'n_syn_apical_tuft_shaft_postsyn': 0,
#  'n_syn_apical_tuft_no_head_postsyn': 0,
#  'n_syn_apical_shaft_head_postsyn': 33,
#  'n_syn_apical_shaft_neck_postsyn': 0,
#  'n_syn_apical_shaft_shaft_postsyn': 35,
#  'n_syn_apical_shaft_no_head_postsyn': 14,
#  'n_syn_oblique_head_postsyn': 0,
#  'n_syn_oblique_neck_postsyn': 0,
#  'n_syn_oblique_shaft_postsyn': 0,
#  'n_syn_oblique_no_head_postsyn': 0,
#  'n_syn_soma_no_label_presyn': 0,
#  'n_syn_soma_no_label_postsyn': 36,
#  'n_syn_apical_total_head_presyn': 0,
#  'n_syn_apical_total_head_postsyn': 33,
#  'n_syn_apical_total_neck_presyn': 0,
#  'n_syn_apical_total_neck_postsyn': 0,
#  'n_syn_apical_total_shaft_presyn': 1,
#  'n_syn_apical_total_shaft_postsyn': 40,
#  'n_syn_apical_total_no_head_presyn': 0,
#  'n_syn_apical_total_no_head_postsyn': 14,
#  'n_syn_axon_ais_postsyn': 0,
#  'axon_branch_length_median': 20.220026414892537,
#  'axon_branch_length_mean': 20.220026414892537,
#  'axon_n_short_branches': 0,
#  'axon_n_long_branches': 0,
#  'axon_n_medium_branches': 1,
#  'axon_bbox_volume': 0.0003879707171463363,
#  'axon_bbox_x_min': 294273.0,
#  'axon_bbox_y_min': 678421.2,
#  'axon_bbox_z_min': 789537.0,
#  'axon_bbox_x_max': 297759.00634505705,
#  'axon_bbox_y_max': 694407.0,
#  'axon_bbox_z_max': 796499.0381566327,
#  'axon_bbox_x_min_soma_relative': -819.4139694180922,
#  'axon_bbox_y_min_soma_relative': 7527.59327015013,
#  'axon_bbox_z_min_soma_relative': -4666.913531376049,
#  'axon_bbox_x_max_soma_relative': 2666.592375638953,
#  'axon_bbox_y_max_soma_relative': 23513.393270150176,
#  'axon_bbox_z_max_soma_relative': 2295.1246252566343,
#  'axon_n_limbs': 1,
#  'axon_soma_angle_max': 165.41,
#  'axon_soma_angle_min': 165.41,
#  'apical_branch_length_median': 29.21709397404419,
#  'apical_branch_length_mean': 75.14610023029535,
#  'apical_n_short_branches': 0,
#  'apical_n_long_branches': 1,
#  'apical_n_medium_branches': 2,
#  'apical_bbox_volume': 0.14751477318625902,
#  'apical_bbox_x_min': 268589.4765485554,
#  'apical_bbox_y_min': 477604.30692323495,
#  'apical_bbox_z_min': 791800.0,
#  'apical_bbox_x_max': 303376.2961011962,
#  'apical_bbox_y_max': 662494.0,
#  'apical_bbox_z_max': 814735.4935374598,
#  'apical_bbox_x_min_soma_relative': -26502.93742086267,
#  'apical_bbox_y_min_soma_relative': -193289.29980661487,
#  'apical_bbox_z_min_soma_relative': -2403.913531376049,
#  'apical_bbox_x_max_soma_relative': 8283.882131778111,
#  'apical_bbox_y_max_soma_relative': -8399.606729849824,
#  'apical_bbox_z_max_soma_relative': 20531.580006083706,
#  'apical_n_limbs': 1,
#  'apical_soma_angle_max': 21.63,
#  'apical_soma_angle_min': 21.63,
#  'basal_branch_length_median': 24.101836888514104,
#  'basal_branch_length_mean': 40.31100797806262,
#  'basal_n_short_branches': 0,
#  'basal_n_long_branches': 1,
#  'basal_n_medium_branches': 6,
#  'basal_bbox_volume': 0.3494717346526398,
#  'basal_bbox_x_min': 267252.8017877262,
#  'basal_bbox_y_min': 638374.0224053463,
#  'basal_bbox_z_min': 792517.8101289792,
#  'basal_bbox_x_max': 400795.08274561644,
#  'basal_bbox_y_max': 718240.4362414976,
#  'basal_bbox_z_max': 825284.2367586675,
#  'basal_bbox_x_min_soma_relative': -27839.61218169192,
#  'basal_bbox_y_min_soma_relative': -32519.58432450355,
#  'basal_bbox_z_min_soma_relative': -1686.1034023968969,
#  'basal_bbox_x_max_soma_relative': 105702.66877619835,
#  'basal_bbox_y_max_soma_relative': 47346.82951164781,
#  'basal_bbox_z_max_soma_relative': 31080.32322729146,
#  'basal_n_limbs': 5,
#  'basal_soma_angle_max': 156.24,
#  'basal_soma_angle_min': 65.17,
#  'dendrite_branch_length_median': 26.659465431279145,
#  'dendrite_branch_length_mean': 50.76153565373244,
#  'dendrite_n_short_branches': 0,
#  'dendrite_n_long_branches': 2,
#  'dendrite_n_medium_branches': 8,
#  'dendrite_bbox_volume': 1.07601921596774,
#  'dendrite_bbox_x_min': 267252.8017877262,
#  'dendrite_bbox_y_min': 477604.30692323495,
#  'dendrite_bbox_z_min': 791800.0,
#  'dendrite_bbox_x_max': 400795.08274561644,
#  'dendrite_bbox_y_max': 718240.4362414976,
#  'dendrite_bbox_z_max': 825284.2367586675,
#  'dendrite_bbox_x_min_soma_relative': -27839.61218169192,
#  'dendrite_bbox_y_min_soma_relative': -193289.29980661487,
#  'dendrite_bbox_z_min_soma_relative': -2403.913531376049,
#  'dendrite_bbox_x_max_soma_relative': 105702.66877619835,
#  'dendrite_bbox_y_max_soma_relative': 47346.82951164781,
#  'dendrite_bbox_z_max_soma_relative': 31080.32322729146,
#  'dendrite_n_limbs': 6,
#  'dendrite_soma_angle_max': 156.24,
#  'dendrite_soma_angle_min': 21.63,
#  'run_time': 153.8,
#  'axon_on_dendrite_merges_error_area': 906.38,
#  'axon_on_dendrite_merges_error_length': 584.4,
#  'high_degree_branching_error_area': 0.0,
#  'high_degree_branching_error_length': 0.0,
#  'low_degree_branching_error_area': 0.0,
#  'low_degree_branching_error_length': 0.0,
#  'high_degree_branching_dendrite_error_area': nan,
#  'high_degree_branching_dendrite_error_length': nan,
#  'width_jump_up_dendrite_error_area': 0.0,
#  'width_jump_up_dendrite_error_length': 0.0,
#  'width_jump_up_axon_error_area': 0.0,
#  'width_jump_up_axon_error_length': 0.0,
#  'double_back_dendrite_error_area': 0.0,
#  'double_back_dendrite_error_length': 0.0,
#  'orientation_tuning_rad': nan,
#  'tuning_fidelity': nan,
#  'oracle': nan,
#  'directional_tuning_rad': nan,
#  'functionally_tuned': nan,
#  'gcn_emedding': array([2.46958272e-03, 6.91548288e-02, 9.28152382e-01, 5.36028056e-05,
#         1.53845050e-07, 2.31653772e-07, 1.67843536e-04, 4.24199300e-07,
#         1.17629405e-07, 6.94175029e-08, 7.82452844e-07]),
#  'manual_cell_type': 'excitatory',
#  'external_manual_proofread': False,
#  'y_coordinate': np.float64(375.8936067298498),
#  'manual_cell_type_fine': None,
#  'gnn_cell_type_fine': '5P-IT',
#  'gnn_cell_type': 'excitatory',
#  'gnn_cell_type_fine_prob': 0.9281523823738098,
#  'gnn_cell_type_fine_2': '4P',
#  'gnn_cell_type_fine_prob_2': 0.06915482878684998,
#  'gnn_cell_type_2': 'excitatory',
#  'gnn_cell_type_fine_3': '23P',
#  'gnn_cell_type_fine_prob_3': 0.0024695827160030603,
#  'gnn_cell_type_3': 'excitatory',
#  'gnn_cell_type_fine_4': '6P-IT',
#  'gnn_cell_type_fine_prob_4': 0.00016784353647381067,
#  'gnn_cell_type_4': 'excitatory',
#  'gnn_cell_type_fine_5': '5P-NP',
#  'gnn_cell_type_fine_prob_5': 5.360280556487851e-05,
#  'gnn_cell_type_5': 'excitatory',
#  'gnn_cell_type_fine_6': 'NGC',
#  'gnn_cell_type_fine_prob_6': 7.824528438504785e-07,
#  'gnn_cell_type_6': 'inhibitory',
#  'gnn_cell_type_fine_7': 'BC',
#  'gnn_cell_type_fine_prob_7': 4.2419929968673387e-07,
#  'gnn_cell_type_7': 'inhibitory',
#  'gnn_cell_type_fine_8': '6P-CT',
#  'gnn_cell_type_fine_prob_8': 2.3165377172063017e-07,
#  'gnn_cell_type_8': 'excitatory',
#  'gnn_cell_type_fine_9': '5P-PT',
#  'gnn_cell_type_fine_prob_9': 1.5384505047677521e-07,
#  'gnn_cell_type_9': 'excitatory',
#  'gnn_cell_type_fine_10': 'BPC',
#  'gnn_cell_type_fine_prob_10': 1.1762940488324602e-07,
#  'gnn_cell_type_10': 'inhibitory',
#  'gnn_cell_type_fine_11': 'MC',
#  'gnn_cell_type_fine_prob_11': 6.941750285704984e-08,
#  'gnn_cell_type_11': 'inhibitory',
#  'u': '864691136965808334_0',
#  'in_degree': 1,
#  'out_degree': 0,
#  'total_degree': 1}

# %% [markdown]
# # Generate the optimal centroid for given attribute

# %%
centroid_x_nm': 295092.4139694181,
'centroid_y_nm': 670893.6067298498,
'centroid_z_nm': 794203.913531376,

# %%
"""
Purpose
-------
Want to generate the 
voxel_to_nm_scaling 
"""

# %% [markdown]
# # Optimal region finding function

# %%
import pandas as pd

def nodes_to_dataframe(G, nodes, attrs=None):
    """
    Create a DataFrame of node attributes for given nodes.
    If attrs=None, include all attributes.
    """
    if type(attrs) == str:
        attrs = [attrs]
    records = []
    for n in nodes:
        node_attrs = G.nodes[n].copy()
        node_attrs["node_id"] = n
        if attrs:
            node_attrs = {k: node_attrs.get(k) for k in ["node_id"] + list(attrs)}
        records.append(node_attrs)
    return pd.DataFrame(records)

# %%
best_nodes = ['864691136023767609_0',
 '864691136965808334_0',
 '864691135617737103_0',
 '864691134939970403_0',
 '864691135497605139_0',
 '864691135366598130_0',
 '864691135385264469_0',
 '864691136296739099_0',
 '864691135939472385_0',
 '864691136023727417_0']

attr_to_use = "apical_mesh_volume"

df = nodes_to_dataframe(
    G,
    best_nodes,
    [attr_to_use]
)

df
# Out:
#                 node_id  apical_mesh_volume
# 0  864691136023767609_0                5772
# 1  864691136965808334_0                 172
# 2  864691135617737103_0                   0
# 3  864691134939970403_0                2033
# 4  864691135497605139_0                   0
# 5  864691135366598130_0                   0
# 6  864691135385264469_0                  64
# 7  864691136296739099_0                   0
# 8  864691135939472385_0                   0
# 9  864691136023727417_0                  54

# %%
import numpy as np

def find_best_region(
    G,
    radius,
    attr_to_use,
    objective = "sum",
    shape = "sphere",
    default_attr_value = 0.0,
    center_attribute = "centroid_x_nm",
    tie_break = "first",
    ):

    """
    Find the node-centered region (sphere/cube/circle/square) of given radius
    that maximizes an objective over a node attribute.

    Returns:
      {
        "center_node": node id of best center,
        "centroid": (x,y,z) of center,
        "nodes_in_region": list of nodes in best region,
        "score": best objective value,
        "df": dataframe of nodes and there attributes of interest
      }
    """
    nodes = list(G.nodes())

    centroid_names = [center_attribute.replace("_x",f"_{k}")
                      for k in ['x','y','z']]
    
    X = np.array([G.nodes[n].get(centroid_names[0], np.nan) for n in nodes], dtype=float)
    Y = np.array([G.nodes[n].get(centroid_names[1], np.nan) for n in nodes], dtype=float)
    Z = np.array([G.nodes[n].get(centroid_names[2], np.nan) for n in nodes], dtype=float)

    if np.isnan(X).any() or np.isnan(Y).any() or np.isnan(Z).any():
        raise ValueError("All nodes must have centroid_x_nm, centroid_y_nm, centroid_z_nm.")

    # Attribute values (only used if attr_to_use is not None and objective != "count")
    vals = None
    if objective != "count" and attr_to_use is not None:
        vals = np.array([G.nodes[n].get(attr_to_use, default_attr_value) for n in nodes], dtype=float)

    # Shape config
    shape = shape.lower()
    if shape not in {"sphere", "cube", "circle", "square"}:
        raise ValueError("shape must be one of: 'sphere', 'cube', 'circle', 'square'.")

    use_3d = shape in {"sphere", "cube"}
    use_euclidean = shape in {"sphere", "circle"}  # else Chebyshev (axis-aligned box)

    coords = np.stack([X, Y, Z], axis=1) if use_3d else np.stack([X, Y], axis=1)
    r = float(radius)
    r2 = r * r

    # Objective resolver
    if callable(objective):
        agg_fn = objective  # expects agg_fn(arr) -> float
        needs_attr = (objective != "count")
    else:
        key = str(objective).lower()
        needs_attr = (key != "count")
        if key in ("sum",):
            agg_fn = np.sum
        elif key in ("mean", "avg", "average"):
            def agg_fn(a): return np.mean(a) if a.size else -np.inf
        elif key == "max":
            def agg_fn(a): return np.max(a) if a.size else -np.inf
        elif key == "min":
            def agg_fn(a): return np.min(a) if a.size else np.inf  # note: maximizing min favors larger mins
        elif key == "median":
            def agg_fn(a): return np.median(a) if a.size else -np.inf
        elif key == "count":
            def agg_fn(a): return float(a.size)
        else:
            raise ValueError("objective must be one of: sum, mean/avg, max, min, median, count, or a callable")

    if needs_attr and vals is None:
        # user asked for an attr-based objective but gave no attr_to_use
        raise ValueError("attr_to_use must be provided for objectives other than 'count' or a custom callable that ignores input.")

    best_score = -np.inf
    best_idx = -1
    best_nodes = None
    best_size = -1

    # Try fast cKDTree, else NumPy fallback
    try:
        from scipy.spatial import cKDTree
        tree = cKDTree(coords)
        p = np.inf if not use_euclidean else 2
        neighbor_lists = tree.query_ball_point(coords, r, p=p)

        for i, neigh in enumerate(neighbor_lists):
            if needs_attr:
                a = vals[neigh]
            else:
                # pass dummy array of ones so agg_fn can use .size for "count"
                a = np.ones(len(neigh), dtype=float)
            score = float(agg_fn(a))
            if (score > best_score) or (score == best_score and tie_break == "largest" and len(neigh) > best_size):
                best_score = score
                best_idx = i
                best_nodes = [nodes[j] for j in neigh]
                best_size = len(neigh)

    except Exception:
        # O(N^2) fallback
        for i in range(coords.shape[0]):
            delta = coords - coords[i]
            if use_euclidean:
                mask = (delta * delta).sum(axis=1) <= r2
            else:
                mask = np.max(np.abs(delta), axis=1) <= r
            idxs = np.flatnonzero(mask)

            if needs_attr:
                a = vals[idxs]
            else:
                a = np.ones(idxs.size, dtype=float)

            score = float(agg_fn(a))
            if (score > best_score) or (score == best_score and tie_break == "largest" and idxs.size > best_size):
                best_score = score
                best_idx = i
                best_nodes = [nodes[j] for j in idxs]
                best_size = idxs.size

    center_node = nodes[best_idx]
    centroid = (float(X[best_idx]), float(Y[best_idx]), float(Z[best_idx]))

    

    return {
        "center_node": center_node,
        "centroid": centroid,
        "nodes_in_region": best_nodes,
        "n_nodes": len(best_nodes),
        "score": best_score,
        "attr_df":nodes_to_dataframe(
            G,
            best_nodes,
            [attr_to_use]
        )
    }

# %%
r2 = find_best_region(
    G, 
    radius=100_000, 
    attr_to_use="axon_skeletal_length", 
    objective="mean", 
    shape="sphere"
)

r2
# Out:
# {'center_node': '864691135348268247_0',
#  'centroid': (1255918.5531486792, 687405.4635343975, 980714.5568474651),
#  'nodes_in_region': ['864691135700409211_0',
#   '864691135122396967_0',
#   '864691136194102230_0',
#   '864691136296702747_0',
#   '864691135385422677_0',
#   '864691135516212947_0',
#   '864691135571164653_0',
#   '864691135479922884_0',
#   '864691136582363810_0',
#   '864691135064986948_0',
#   '864691136031872699_0',
#   '864691135974780527_0',
#   '864691135385295445_0',
#   '864691136378790101_0',
#   '864691135382467290_0',
#   '864691135544370162_0',
#   '864691136020282616_0',
#   '864691135975633475_0',
#   '864691135738609812_0',
#   '864691136811995507_0',
#   '864691136965901006_0',
#   '864691135081738743_0',
#   '864691135718541617_0',
#   '864691137197345601_0',
#   '864691135560809441_0',
#   '864691135697679637_0',
#   '864691135181773570_0',
#   '864691135809608652_0',
#   '864691135617770383_0',
#   '864691135012409078_0',
#   '864691135104014925_0',
#   '864691135945465892_0',
#   '864691136536113826_0',
#   '864691135809451468_0',
#   '864691136553535650_0',
#   '864691135947019873_0',
#   '864691135385293397_0',
#   '864691136003896778_0',
#   '864691135104301389_0',
#   '864691135467566732_0',
#   '864691136544566690_0',
#   '864691135385241941_0',
#   '864691135382972139_0',
#   '864691135692720319_0',
#   '864691135937382709_0',
#   '864691135994821546_0',
#   '864691135684426167_0',
#   '864691135013270934_0',
#   '864691136558575778_0',
#   '864691135256522415_0',
#   '864691135748686121_0',
#   '864691135993804490_0',
#   '864691135581592429_0',
#   '864691135730194617_0',
#   '864691135732623764_0',
#   '864691135337700070_0',
#   '864691135733138836_0',
#   '864691136966079694_0',
#   '864691135937410869_0',
#   '864691135474648128_0',
#   '864691135687233248_0',
#   '864691135654069954_0',
#   '864691136534850210_0',
#   '864691136041019222_0',
#   '864691136422859823_0',
#   '864691135393958133_0',
#   '864691135937210116_0',
#   '864691135748588841_0',
#   '864691135772037371_0',
#   '864691135720524180_0',
#   '864691135700620667_0',
#   '864691135777145021_0',
#   '864691135614140107_0',
#   '864691135340996549_0',
